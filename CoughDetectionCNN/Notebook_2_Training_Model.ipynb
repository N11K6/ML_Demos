# %% [markdown]
# # Part II: Model Building, Training and Testing

# %% [markdown]
# Now that we have a relatively tidy and balanced dataset of images, it is time to use them to train a classification model. We will be designing a Convolutional Neural Network to perform this task.
#
# As CNNs require a lot of processing power to be trained, we will make use of the GPUs available through Google's colab service to complete this task. Therefore, there will be a couple of steps taken along the way to take care of that. In any case, our trained model can be stored and deployed in any machine, offline and without the need of GPUs.

# %%
# Dependencies: 

import os
from os import walk

import numpy as np
import librosa as lb
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from tensorflow import keras

from google.colab import drive

# %% [markdown]
# ## Loading audio data

# %%
# This step is to mount Google drive on this notebook:
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# With the Google Drive mounted, we can import our dataset to colab:

# %%
TRAIN_DIR = '/content/drive/MyDrive/Training/Directory'
TEST_DIR = '/content/drive/MyDrive/Testing/Directory'

# %% [markdown]
# ### Extract Features from Audio Data:
#
# First let's define a short function to extract the features from the audio files. In this case, the features are the MFCCs calculated via librosa, and they are stored as numpy arrays. Normalization of each audio file between 0 and 1 will also help shape up more manageable features.

# %%
def get_MFCC(path):
    '''
    Extract MFCCs from audio file in path.
    '''
    # Load audio, default sample rate is 22050 Hz
    sound, sample_rate = lb.load(path)
    
    ''' 
    Normalize within range 0,1. The *if* statement is to avoid getting 
    *nan* values from blank files that have made it to the dataset.
    '''
    if np.max(sound) != np.min(sound):
        sound /= np.max(np.abs(sound))
    
    # Calculate MFCCs
    mfcc = lb.feature.mfcc(y=sound, sr=sample_rate)
    
    return mfcc

# %% [markdown]
# A function can be thus defined to calculate the MFCCs for all audio files in a directory and store them in an array:

# %%
def get_features(directory):

  filepaths = [] 

  for root, dirs, files in os.walk(directory):
    for name in files:
      filepaths.append(os.path.join(root,name))

  mfccs = []

  for i, filepath in enumerate(filepaths):
    mfccs.append(get_MFCC(filepath))
    if i % 10 == 0:
      print(i)

  mfccs = np.array(mfccs)

  return mfccs

# %% [markdown]
# Since the directories were arranged by label, we load the cough and non-cough audio separately. First we go through the cough .wav files to extract the MFCC features and stack them on an array *mfcc_0*.
#
# We can see that we have 647 samples, and each MFCC has a size (20, 44). The latter translates to 20 ceptral coefficients and 44 frequency bins.

# %%
mfcc_0 = get_features(TRAIN_DIR+'/positives/')
np.save('mfccs_pos.npy', mfcc_0)
print(mfcc_0.shape)
# Out:
# (647, 20, 44)

# %% [markdown]
# Now we do the same to extract the features from the non-cough audio files.

# %%
mfcc_1 = get_features(TRAIN_DIR+'/negatives/')
np.save('mfccs_neg.npy', mfcc_1)
print(mfcc_1.shape)
# Out:
# (836, 20, 44)

# %% [markdown]
# The extracted feature arrays can be stored as .npy files, which can be loaded quickly and easily.

# %%
PATH_MFCC0 = '/content/drive/MyDrive/mfccs_pos.npy'
PATH_MFCC1 = '/content/drive/MyDrive/mfccs_neg.npy'

# %% [markdown]
# We can check on the feature arrays again:

# %%
mfcc_0 = np.load(PATH_MFCC0)
print('Shape of positives array: ', mfcc_0.shape)

mfcc_1 = np.load(PATH_MFCC1)
print('Shape of negatives array: ', mfcc_1.shape)
# Out:
# Shape of positives array:  (647, 20, 44)
# Shape of negatives array:  (836, 20, 44)

# %% [markdown]
# ### Format Input Data
#
# Although we have all the features we need to train the model loaded up, we need to bring them in a format that can be sent to a tensorflow neural network. To do that, we concatenate the arrays corresponding to the two classes, and we also expand towards an extra singular dimension.
#
# We also need to take care of the labels. Since we have loaded up the two classes separately, we can generate a label array simply by joining two arrays of zeros and ones with lengths corresponding to the number of samples in each class.

# %%
# Join classes:
X = np.concatenate((mfcc_0, mfcc_1))
# Expand dimension:
X = np.expand_dims(X, axis=-1)
print('Shape of input feature tensor: ', X.shape)

# Generate labels:
y_0 = np.zeros(mfcc_0.shape[0])
y_1 = np.ones(mfcc_1.shape[0])
# Join classes:
y = np.concatenate((y_0, y_1))
y = pd.Series(y, dtype=int)
# Arrange dimensionality:
y = pd.get_dummies(y).values
print('Shape of label tensor: ', y.shape)
# Out:
# Shape of input feature tensor:  (1483, 20, 44, 1)
# Shape of label tensor:  (1483, 2)

# %% [markdown]
# One last step is to normalize the feature tensors so that they lie within the range 0 to 1. This can help the training process in efficiency.
#
# We can store the values *X_min* and *X_ptp* to appropriately normalize any subsequent test data.

# %%
# Normalize training feature data within 0,1
X_min = np.min(X)
X_ptp = np.ptp(X)

X = (X - X_min)/X_ptp

# %%
print(X_min,X_ptp)
# Out:
# -1131.3708 1398.0525

# %% [markdown]
# ## Convolutional Neural Network
#
# Now that our data is ready, it is time to design the convolutional neural network architecture, and set our training parameters. We will use three 2D convolutional layers, with additional batch normalization and dropout layers to improve upon the training process.
# Notice the input size is the same as we defined for our data above, 20x40x1, and the output size is 2, corresponding to two classes, activated via a softmax function.

# %%
# Input stage
mfcc_input=keras.layers.Input(shape=(20,44,1), name = "mfccInput")

# 1st Convolution stage
x=keras.layers.Conv2D(32,3,strides=(1,1),padding='same', name = 'conv1')(mfcc_input)
x=keras.layers.BatchNormalization(name = 'bnorm1')(x)
x=keras.layers.Activation(keras.activations.relu, name = 'act1')(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid', name = 'pool1')(x)
x=keras.layers.Dropout(0.1, name='drop1')(x)

# 2nd Convolution stage
x=keras.layers.Conv2D(64,3,strides=(1,1),padding='same', name = 'conv2')(x)
x=keras.layers.BatchNormalization(name = 'bnorm2')(x)
x=keras.layers.Activation(keras.activations.relu, name = 'act2')(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid', name = 'pool2')(x)
x=keras.layers.Dropout(0.1, name='drop2')(x)

# 3rd Convolution stage
x=keras.layers.Conv2D(64,3,strides=(1,1),padding='same', name = 'conv3')(x)
x=keras.layers.BatchNormalization(name = 'bnorm3')(x)
x=keras.layers.Activation(keras.activations.relu, name = 'act3')(x)
x=keras.layers.MaxPooling2D(pool_size=2,padding='valid', name = 'pool3')(x)
x=keras.layers.Dropout(0.1, name='drop3')(x)

# Fully Connected stage
x=keras.layers.Flatten(name = 'flatten')(x)
x=keras.layers.Dense(units = 64, activation = 'relu', name = 'dense')(x)
x=keras.layers.Dropout(0.2, name='drop4')(x)

# Output stage
mfcc_output=keras.layers.Dense(2, activation='softmax', name = 'out')(x)

mfcc_model=keras.Model(mfcc_input, mfcc_output, name="mfccModel")

# %% [markdown]
# Let's have a look at the summary of our model. 97,218 trainable parameters might seem a lot, but it's actually rather simple for a convolutional neural network.

# %%
mfcc_model.summary()
# Out:
# Model: "mfccModel"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mfccInput (InputLayer)       [(None, 20, 44, 1)]       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 20, 44, 32)        320
# _________________________________________________________________
# bnorm1 (BatchNormalization)  (None, 20, 44, 32)        128
# _________________________________________________________________
# act1 (Activation)            (None, 20, 44, 32)        0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 10, 22, 32)        0
# _________________________________________________________________
# drop1 (Dropout)              (None, 10, 22, 32)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 10, 22, 64)        18496
# _________________________________________________________________
# bnorm2 (BatchNormalization)  (None, 10, 22, 64)        256
# _________________________________________________________________
# act2 (Activation)            (None, 10, 22, 64)        0
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 5, 11, 64)         0
# _________________________________________________________________
# drop2 (Dropout)              (None, 5, 11, 64)         0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 5, 11, 64)         36928
# _________________________________________________________________
# bnorm3 (BatchNormalization)  (None, 5, 11, 64)         256
# _________________________________________________________________
# act3 (Activation)            (None, 5, 11, 64)         0
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 2, 5, 64)          0
# _________________________________________________________________
# drop3 (Dropout)              (None, 2, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 640)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                41024
# _________________________________________________________________
# drop4 (Dropout)              (None, 64)                0
# _________________________________________________________________
# out (Dense)                  (None, 2)                 130
# =================================================================
# Total params: 97,538
# Trainable params: 97,218
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# Another visualization available through keras is direct image export:

# %%
keras.utils.plot_model(mfcc_model, "net.png", show_shapes=True)

# %% [markdown]
# Now that the design is finalized, we will compile the model using *binary crossentropy* as loss, *accuracy* as the metric, and use the optimizer *adam* with a starting learning rate of 0.001. It is also useful to include a couple of callbacks so that the training becomes more efficient. We set an early stopping callback as well as a method to reduce the learning rate on plateaus of the loss function.

# %%
mfcc_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
keras.backend.set_value(mfcc_model.optimizer.learning_rate, 0.001)

my_callbacks = [keras.callbacks.EarlyStopping(patience=6),
                keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                patience=3, min_lr=0.00001,mode='min')]

# %% [markdown]
# ### Model Training:
#
# As we have all the data and labels the way we need them, we can split it into training and validation sets with the classic sklearn method.

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# The training can commence. Max number of epochs is set to 50, and batch size of 24 samples is used.

# %%
history=mfcc_model.fit(
    X_train,
    y_train,
    validation_data=(X_val,y_val),
    epochs=50,
    verbose=1,
    batch_size=24,
    callbacks=my_callbacks
)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 1s 10ms/step - loss: 0.8205 - accuracy: 0.5892 - val_loss: 0.8308 - val_accuracy: 0.5421
# Epoch 2/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3300 - accuracy: 0.8690 - val_loss: 1.0800 - val_accuracy: 0.5421
# Epoch 3/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.2641 - accuracy: 0.8968 - val_loss: 0.6727 - val_accuracy: 0.5421
# Epoch 4/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1747 - accuracy: 0.9370 - val_loss: 0.6994 - val_accuracy: 0.5421
# Epoch 5/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1393 - accuracy: 0.9406 - val_loss: 0.6028 - val_accuracy: 0.5152
# Epoch 6/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1475 - accuracy: 0.9436 - val_loss: 0.8088 - val_accuracy: 0.4579
# Epoch 7/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1181 - accuracy: 0.9618 - val_loss: 0.3800 - val_accuracy: 0.8451
# Epoch 8/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0902 - accuracy: 0.9726 - val_loss: 0.9492 - val_accuracy: 0.4579
# Epoch 9/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1200 - accuracy: 0.9553 - val_loss: 0.1421 - val_accuracy: 0.9529
# Epoch 10/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0919 - accuracy: 0.9675 - val_loss: 0.3856 - val_accuracy: 0.8114
# Epoch 11/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0906 - accuracy: 0.9673 - val_loss: 0.3594 - val_accuracy: 0.8384
# Epoch 12/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0866 - accuracy: 0.9694 - val_loss: 4.0394 - val_accuracy: 0.5421
# Epoch 13/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0788 - accuracy: 0.9717 - val_loss: 0.5402 - val_accuracy: 0.7576
# Epoch 14/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0623 - accuracy: 0.9720 - val_loss: 0.1172 - val_accuracy: 0.9461
# Epoch 15/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0642 - accuracy: 0.9760 - val_loss: 0.0570 - val_accuracy: 0.9764
# Epoch 16/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0496 - accuracy: 0.9854 - val_loss: 0.0430 - val_accuracy: 0.9933
# Epoch 17/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0568 - accuracy: 0.9804 - val_loss: 0.0387 - val_accuracy: 0.9899
# Epoch 18/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0556 - accuracy: 0.9835 - val_loss: 0.0378 - val_accuracy: 0.9865
# Epoch 19/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0518 - accuracy: 0.9839 - val_loss: 0.0345 - val_accuracy: 0.9899
# Epoch 20/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0450 - accuracy: 0.9857 - val_loss: 0.2187 - val_accuracy: 0.9091
# Epoch 21/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0649 - accuracy: 0.9803 - val_loss: 0.1291 - val_accuracy: 0.9428
# Epoch 22/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0503 - accuracy: 0.9783 - val_loss: 0.0308 - val_accuracy: 0.9899
# Epoch 23/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0490 - accuracy: 0.9854 - val_loss: 0.1058 - val_accuracy: 0.9428
# Epoch 24/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0536 - accuracy: 0.9901 - val_loss: 0.0875 - val_accuracy: 0.9562
# Epoch 25/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0399 - accuracy: 0.9885 - val_loss: 0.1932 - val_accuracy: 0.9226
# Epoch 26/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0503 - accuracy: 0.9766 - val_loss: 0.0651 - val_accuracy: 0.9764
# Epoch 27/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0500 - accuracy: 0.9807 - val_loss: 0.0377 - val_accuracy: 0.9933
# Epoch 28/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0556 - accuracy: 0.9846 - val_loss: 0.0290 - val_accuracy: 0.9933
# Epoch 29/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0474 - accuracy: 0.9868 - val_loss: 0.0270 - val_accuracy: 0.9899
# Epoch 30/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0302 - accuracy: 0.9929 - val_loss: 0.0270 - val_accuracy: 0.9865
# Epoch 31/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0392 - accuracy: 0.9886 - val_loss: 0.0263 - val_accuracy: 0.9899
# Epoch 32/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0368 - accuracy: 0.9878 - val_loss: 0.0264 - val_accuracy: 0.9933
# Epoch 33/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0385 - accuracy: 0.9859 - val_loss: 0.0257 - val_accuracy: 0.9899
# Epoch 34/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0401 - accuracy: 0.9870 - val_loss: 0.0255 - val_accuracy: 0.9899
# Epoch 35/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.0435 - accuracy: 0.9874 - val_loss: 0.0257 - val_accuracy: 0.9933
# Epoch 36/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0463 - accuracy: 0.9898 - val_loss: 0.0250 - val_accuracy: 0.9899
# Epoch 37/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 0.9873 - val_loss: 0.0251 - val_accuracy: 0.9899
# Epoch 38/50
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0321 - accuracy: 0.9881 - val_loss: 0.0257 - val_accuracy: 0.9865
# Epoch 39/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0601 - accuracy: 0.9716 - val_loss: 0.0251 - val_accuracy: 0.9933
# Epoch 40/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0388 - accuracy: 0.9886 - val_loss: 0.0249 - val_accuracy: 0.9933
# Epoch 41/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0508 - accuracy: 0.9841 - val_loss: 0.0250 - val_accuracy: 0.9899
# Epoch 42/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0301 - accuracy: 0.9944 - val_loss: 0.0249 - val_accuracy: 0.9899
# Epoch 43/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0502 - accuracy: 0.9845 - val_loss: 0.0283 - val_accuracy: 0.9933
# Epoch 44/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0382 - accuracy: 0.9880 - val_loss: 0.0278 - val_accuracy: 0.9933
# Epoch 45/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0337 - accuracy: 0.9887 - val_loss: 0.0248 - val_accuracy: 0.9899
# Epoch 46/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0581 - accuracy: 0.9778 - val_loss: 0.0250 - val_accuracy: 0.9933
# Epoch 47/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0337 - accuracy: 0.9930 - val_loss: 0.0253 - val_accuracy: 0.9933
# Epoch 48/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0510 - accuracy: 0.9806 - val_loss: 0.0254 - val_accuracy: 0.9933
# Epoch 49/50
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0459 - accuracy: 0.9886 - val_loss: 0.0248 - val_accuracy: 0.9933
# Epoch 50/50
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0490 - accuracy: 0.9879 - val_loss: 0.0256 - val_accuracy: 0.9933

# %% [markdown]
# Training seems to have gone well. We reached a 99% validation accuracy during the final epoch, even higher than the training accuracy. Also the early stopping callback was activated, and training stopped at the 13th epoch. We can visualize the process:

# %%
def plot_training(history):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  epochs = range(len(acc))
  
  plt.plot(epochs, acc, 'r.')
  plt.plot(epochs, val_acc, 'r')
  plt.title('Training and validation accuracy')
  
  plt.figure()
  plt.plot(epochs, loss, 'r.')
  plt.plot(epochs, val_loss, 'r-')
  plt.title('Training and validation loss')
  plt.show()
  
plot_training(history)

# %% [markdown]
# We can notice irregularities early on. These are likely due to the effect of the Dropout layers, which shut off a number of neurons at each go during training to avoid overfitting.
# Other than this, we have a standard trend of increasing accuracy and decreasing loss.

# %% [markdown]
# ### Evaluate the Model on Test Data:
#
# Finally we will evaluate our model using a small selection of test data never seen by the model during training. To make sure that these samples are completely new to our model, the coughing audio samples here are generated from entirely different clips than those used in the making of the training datasets, so we are introducing some entirely new 'voices' to our model.
#
# Let's load and format our data like we did with the training case:

# %%
mfcc_test = get_features(TEST_DIR+'/test/features')
y_test = np.load(TEST_DIR+'/test/labels')

# %%
y_test = np.zeros(mfcc_test.shape[0]+1)
y_test[-1] = 1.0

y_test = pd.Series(y_test, dtype=int)

y_test = pd.get_dummies(y_test).values
y_test = y_test[:-1]

# %%
# Expand dimensions to match correct input size:
X_test = np.expand_dims(mfcc_test, axis=-1)
print('Shape of test input feature tensor: ', X_test.shape)
print('Shape of test label tensor: ', y_test.shape)
# Out:
# Shape of test input feature tensor:  (52, 20, 44, 1)
# Shape of test label tensor:  (52, 2)

# %% [markdown]
# We will also normalize using the parameters from the training data:

# %%
# Normalize test features:
X_test = (X_test - X_min)/X_ptp

# %% [markdown]
# And finally, time to evaluate the model on the test set using the evaluate function. We will print the loss and accuracy.

# %%
score, acc = mfcc_model.evaluate(X_test,
                                 y_test
                                 )
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1293 - accuracy: 0.9231
# Test score: 0.12927475571632385
# Test accuracy: 0.9230769276618958

# %% [markdown]
# 92% Accuracy was achieved. This is a pretty encouraging performance from a relatively simple and lightweight CNN, especially when we consider the lack of consistency between our coughing audio clips.
#
# We can now store this trained model for deployment.

# %%
mfcc_model.save('/content/drive/MyDrive/Colab_Models/a_fitting_name_for_a_fit_model.h5')
